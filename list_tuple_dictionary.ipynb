# %%
students = {
    101: "Lisha",
    102: "Rohan",
    103: "Ira",
    104: "ABC",
    105: "XYZ"
}

print(students)

del students[103]
print(students)
# Out:
# {101: 'Lisha', 102: 'Rohan', 103: 'Ira', 104: 'ABC', 105: 'XYZ'}
# {101: 'Lisha', 102: 'Rohan', 104: 'ABC', 105: 'XYZ'}

# %%
student_list = ["Lisha", "Rohan", "Ira", "ABC", "XYZ"]
print(student_list)
# Out:
# ['Lisha', 'Rohan', 'Ira', 'ABC', 'XYZ']

# %%
student_tuple = ("Lisha", "Rohan", "Ira", "ABC", "XYZ")
print(student_tuple)
# Out:
# ('Lisha', 'Rohan', 'Ira', 'ABC', 'XYZ')
